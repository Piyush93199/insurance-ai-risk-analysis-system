# %%
import joblib

risk_model = joblib.load(
    '/content/risk_classifier.pkl'
)

# %%
def recommend_policy(risk_name):

    recommendations = {
        "Low Risk": "Basic Insurance Plan",
        "Medium Risk": "Standard Insurance Plan",
        "High Risk": "Premium Insurance Plan"
    }

    return recommendations[risk_name]

# %%
def predict_customer_risk(customer_data):

    prediction = risk_model.predict(customer_data)[0]

    risk_name = risk_labels[prediction]

    recommendation = recommend_policy(risk_name)

    return risk_name, recommendation

# %%
import pandas as pd

sample_customer = pd.DataFrame({

    'age':[45],
    'sex':[1],
    'bmi':[31.5],
    'children':[2],
    'smoker':[1],
    'region':[2]

})

# %%
risk_labels = dict(
    enumerate(le.classes_)
)

print(
    risk
)
# Out:
# High Risk

# %%
risk, recommendation = predict_customer_risk(
    sample_customer
)

print("Customer Risk Level:", risk)
print("Recommended Policy:", recommendation)
# Out:
# Customer Risk Level: High Risk
# Recommended Policy: Premium Insurance Plan

# %%
test_customers = pd.DataFrame({

'age':[25,45,60],

'sex':[0,1,1],

'bmi':[22,30,36],

'children':[0,2,3],

'smoker':[0,1,1],

'region':[1,2,0]

})

predictions = risk_model.predict(
    test_customers
)

for pred in predictions:

    print(
        risk_labels[pred]
    )
# Out:
# Low Risk
# High Risk
# High Risk

# %%
test_customers["Risk Level"] = [

    risk_labels[x]

    for x in predictions

]

test_customers[
    "Recommended Policy"
] = test_customers[
    "Risk Level"
].map({

    "Low Risk":
    "Basic Insurance Plan",

    "Medium Risk":
    "Standard Insurance Plan",

    "High Risk":
    "Premium Insurance Plan"

})

test_customers
# Out:
#    age  sex  bmi  children  smoker  region Risk Level      Recommended Policy
# 0   25    0   22         0       0       1   Low Risk    Basic Insurance Plan
# 1   45    1   30         2       1       2  High Risk  Premium Insurance Plan
# 2   60    1   36         3       1       0  High Risk  Premium Insurance Plan

# %%
joblib.dump(
    risk_model,
    'policy_recommendation_engine.pkl'
)
# Out:
# ['policy_recommendation_engine.pkl']
